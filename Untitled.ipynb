# %%
from lbench.dashboard.app import run_dashboard
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from lbench.dashboard.app import run_dashboard
#
# File ~/code/lsdb-benchmarking/src/lbench/dashboard/app.py:25
#      21 ROOT_DIR = get_lbench_root_dir()
#      23 from dash import jupyter_dash
# ---> 25 jupyter_dash.infer_jupyter_proxy_config()
#      28 # --- Load and cache runs ---
#      29 def load_run_json(run_dir):
#
# File ~/.pyenv/versions/lsdb-benchmarking/lib/python3.12/site-packages/dash/_jupyter.py:266, in JupyterDash.infer_jupyter_proxy_config(self)
#     264     return
#     265 # Assume classic notebook or JupyterLab
# --> 266 _request_jupyter_config()
#
# File ~/.pyenv/versions/lsdb-benchmarking/lib/python3.12/site-packages/dash/_jupyter.py:205, in _request_jupyter_config(timeout)
#     202 if _jupyter_comm_response_received():
#     203     break
# ...

# %%
run_dashboard()
